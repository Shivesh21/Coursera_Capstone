# %% [markdown]
# # IBM Data Science Capstone Project

# %% [markdown]
# # Lets explore the United Kingdom!

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction <a name="introduction"></a>

# %% [markdown]
# One of my life goals is to travel to Manchester to watch a football game at Old Trafford. When I am there I want to visit the area and find the various places of interest around the city. Using data that I found from a UK government site and the foursquare API I will cluster the city of Manchester and see what are the various places/venues of interest there are.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Similar to that of the data used for the labs and previous submission. I will be using the Google Maps API and the FourSquare API to retrieve location data for the UK. Using Folium I will create a map of the UK showcasing the various towns of the country. The venue data from each suburb will be extracted and through the use of the K-means clustering algorithm I will perform clustering on the UK data to group the towns together and observe the results. This project will be of interest to those looking at exploring various countries and comparing the geographical data to that of other developed countries.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# ## First lets extract the geographical data for the UK

# %%
import numpy as np # library to handle data in a vectorized manner
import gmaps
import gmaps.datasets
import pandas as pd # library for data analsysis
from geopy.geocoders import Nominatim
import requests # library to handle requests
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
from bs4 import BeautifulSoup 
print('Libraries imported.')
# Out:
# Libraries imported.

# %%
UK_town_data = pd.read_csv(r'C:\Users\schandrapregaas-maha\Documents\IBM Data Science Program Code\Capstone Project\uk-towns-sample\uk-towns-sample\csv\uk-towns-sample.csv')
UK_town_data.head()
# Out:
#    id          name          county  country grid_reference  easting  \
# 0   1  Aaron's Hill          Surrey  England       SU957435   495783
# 1   2   Abbas Combe        Somerset  England       ST707226   370749
# 2   3      Abberley  Worcestershire  England       SO744675   374477
# 3   4      Abberton           Essex  England       TM006190   600637
# 4   5      Abberton  Worcestershire  England       SO995534   399538
#
#    northing  latitude  longitude  elevation postcode_sector  \
# 0    143522  51.18291   -0.63098         78           GU7 2
# 1    122688  51.00283   -2.41825         91           BA8 0
# 2    267522  52.30522   -2.37574        152           WR6 6
# 3    219093  51.83440    0.91066         44           CO5 7
# 4    253477  52.17955   -2.00817         68          WR10 2
#
#      local_government_area    nuts_region           type
# 0        Waverley District     South East  Suburban Area
# 1  South Somerset District     South West        Village
# 2   Malvern Hills District  West Midlands        Village
# 3      Colchester District        Eastern        Village
# 4        Wychavon District  West Midlands         Hamlet

# %% [markdown]
# I will use geopy to get the coordinates of the UK

# %%
address = 'United Kingdom'

geolocator = Nominatim(user_agent="UK_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the UK are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the UK are 54.7023545, -3.2765753.

# %% [markdown]
# Now I will extract the data I want from this large dataframe

# %%
df_uk_data = UK_town_data[['id','name', 'county', 'latitude', 'longitude', 'type']]
df_uk_data
# Out:
#         id          name           county  latitude  longitude           type
# 0        1  Aaron's Hill           Surrey  51.18291   -0.63098  Suburban Area
# 1        2   Abbas Combe         Somerset  51.00283   -2.41825        Village
# 2        3      Abberley   Worcestershire  52.30522   -2.37574        Village
# 3        4      Abberton            Essex  51.83440    0.91066        Village
# 4        5      Abberton   Worcestershire  52.17955   -2.00817         Hamlet
# ...    ...           ...              ...       ...        ...            ...
# 1797  1813         Ayton     Berwickshire  55.84232   -2.12285        Village
# 1798  1814         Ayton    Tyne and Wear  54.89416   -1.55643  Suburban Area
# 1799  1815  Ayton Castle     Berwickshire  55.84665   -2.12135       Locality
# 1800  1816        Aywick         Shetland  60.56017   -1.03269        Village
# 1801  1817       Azerley  North Yorkshire  54.16753   -1.60288         Hamlet
#
# [1802 rows x 6 columns]

# %%
map_uk = folium.Map(location=[latitude, longitude], zoom_start=7)



# add markers to map
for lat, lng,name, county in zip(df_uk_data['latitude'], df_uk_data['longitude'], df_uk_data['name'], df_uk_data['county']):
    label = '{}, {}'.format(county, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_uk)  
    
map_uk
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_38946d200e4a4272840360a315a22000%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_38946d200e4a4272840360a315a22000%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_38946d200e4a4272840360a315a22000%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_38946d200e4a4272840360a315a22000%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B54.7023545%2C-3.2765753%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%207%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Using the FourSquare API

# %%
CLIENT_ID = '2PAVVWKZKMDYAO3OEF2ATVCHYGHLEDPQYSAAXVCEPUEPPWXA' # your Foursquare ID
CLIENT_SECRET = 'KQE3TXD2B3VUMS4DWZCOY052SFUGI2OLHDWRJQJ3TNOUBBBK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2PAVVWKZKMDYAO3OEF2ATVCHYGHLEDPQYSAAXVCEPUEPPWXA
# CLIENT_SECRET:KQE3TXD2B3VUMS4DWZCOY052SFUGI2OLHDWRJQJ3TNOUBBBK

# %% [markdown]
# ## Lets isolate the data to the city of Manchester

# %%
address = 'Manchester'

geolocator = Nominatim(user_agent="Manchester_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manchester are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manchester are 53.4794892, -2.2451148.

# %%
manchester_data = df_uk_data[df_uk_data['county'] == 'Greater Manchester']
manchester_data.reset_index(drop=True)
manchester_data
# Out:
#         id                       name              county  latitude  \
# 21      22                  Abbey Hey  Greater Manchester  53.46514
# 175    176                      Abram  Greater Manchester  53.50949
# 176    177                 Abram Brow  Greater Manchester  53.50791
# 285    286                       Acre  Greater Manchester  53.55218
# 289    290                      Acres  Greater Manchester  53.55834
# 369    370                    Adswood  Greater Manchester  53.39130
# 378    379                  Affetside  Greater Manchester  53.61778
# 422    423                  Ainsworth  Greater Manchester  53.58799
# 520    536               Alder Forest  Greater Manchester  53.49380
# 533    549                 Alder Root  Greater Manchester  53.53893
# 607    623  Alkrington Garden Village  Greater Manchester  53.53744
# 741    757                        Alt  Greater Manchester  53.52489
# 750    766                   Alt Hill  Greater Manchester  53.51409
# 767    783                 Altrincham  Greater Manchester  53.38809
# 863    879                    Ancoats  Greater Manchester  53.48116
# 1075  1091                 Arden Park  Greater Manchester  53.42001
# 1149  1165                    Ardwick  Greater Manchester  53.47181
# 1388  1404               Ashley Heath  Greater Manchester  53.37106
# 1434  1450               Ashton Heath  Greater Manchester  53.48344
# 1435  1451       Ashton-in-Makerfield  Greater Manchester  53.48858
# 1440  1456          Ashton-under-Lyne  Greater Manchester  53.49033
# 1441  1457         Ashton upon Mersey  Greater Manchester  53.42630
# 1489  1505                     Aspull  Greater Manchester  53.56860
# 1490  1506              Aspull Common  Greater Manchester  53.47827
# 1506  1522                     Astley  Greater Manchester  53.50003
# 1511  1527              Astley Bridge  Greater Manchester  53.60418
# 1514  1530               Astley Green  Greater Manchester  53.49301
# 1589  1605                   Atherton  Greater Manchester  53.52551
# 1675  1691                  Audenshaw  Greater Manchester  53.47211
# 1715  1731                Austerlands  Greater Manchester  53.54604
#
#       longitude           type
# 21     -2.15963       Locality
# 175    -2.59264        Village
# 176    -2.59027  Suburban Area
# 285    -2.09701  Suburban Area
# 289    -2.16579       Locality
# 369    -2.16962  Suburban Area
# 378    -2.37094        Village
# 422    -2.35791        Village
# 520    -2.37547  Suburban Area
# 533    -2.13647  Suburban Area
# 607    -2.19625  Suburban Area
# 741    -2.08473  Suburban Area
# 750    -2.08507         Hamlet
# 767    -2.35146           Town
# 863    -2.22787  Suburban Area
# 1075   -2.12359  Suburban Area
# 1149   -2.22014  Suburban Area
# 1388   -2.34554  Suburban Area
# 1434   -2.62692  Suburban Area
# 1435   -2.63851           Town
# 1440   -2.09380           Town
# 1441   -2.33706  Suburban Area
# 1489   -2.58537        Village
# 1490   -2.54522  Suburban Area
# 1506   -2.45908        Village
# 1511   -2.43151  Suburban Area
# 1514   -2.44962  Suburban Area
# 1589   -2.48723           Town
# 1675   -2.12449       Locality
# 1715   -2.05456  Suburban Area

# %% [markdown]
# ## Lets create a map of Manchester

# %%
map_manchester = folium.Map(location=[latitude, longitude], zoom_start=10)



# add markers to map
for lat, lng,name, county in zip(manchester_data['latitude'], manchester_data['longitude'], manchester_data['name'], manchester_data['county']):
    label = '{}, {}'.format(county, name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manchester)  
    
map_manchester
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_c8fe9c81616c4abba30f29f2fd74b765%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c8fe9c81616c4abba30f29f2fd74b765%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c8fe9c81616c4abba30f29f2fd74b765%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_c8fe9c81616c4abba30f29f2fd74b765%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53.4794892%2C-2.2451148%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %%
county_latitude = manchester_data.loc[21, 'latitude'] # county latitude value
county_longitude = manchester_data.loc[21, 'longitude'] # county longitude value

name = manchester_data.loc[21, 'name'] # county name

print('Latitude and longitude values of {} are {}, {}.'.format(name, 
                                                               county_latitude, 
                                                               county_longitude))
# Out:
# Latitude and longitude values of Abbey Hey are 53.465140000000005, -2.15963.

# %%
LIMIT = 100
RADIUS = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    county_latitude, 
    county_longitude, 
    RADIUS, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=2PAVVWKZKMDYAO3OEF2ATVCHYGHLEDPQYSAAXVCEPUEPPWXA&client_secret=KQE3TXD2B3VUMS4DWZCOY052SFUGI2OLHDWRJQJ3TNOUBBBK&v=20180605&ll=53.465140000000005,-2.15963&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60c4964e62ba9f4e080777f8'},
#  'response': {'headerLocation': 'Gorton North',
#   'headerFullLocation': 'Gorton North, Manchester',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 5,
#   'suggestedBounds': {'ne': {'lat': 53.46964000450001,
#     'lng': -2.1520850415872688},
#    'sw': {'lat': 53.4606399955, 'lng': -2.167174958412731}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '530f41b1498e5f25841b5407',
#        'name': 'Donkey Sanctuary And Therapy Centre',
#        'location': {'lat': 53.46488569011731,
#         'lng': -2.156117265779587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.46488569011731,
#           'lng': -2.156117265779587}],
#         'distance': 234,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4eb1baf03b7b2c5b1d4306ca',
#          'name': 'Stables',
#          'pluralName': 'Stables',
#          'shortName': 'Stables',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/stable_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-530f41b1498e5f25841b5407-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569a5c83498ee77c3abef919',
#        'name': 'Manchester Vacs',
#        'location': {'lat': 53.46697,
#         'lng': -2.1577425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.46697,
#           'lng': -2.1577425}],
#         'distance': 239,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569a5c83498ee77c3abef919-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3c2ea2a2e4b1f77af2e625',
#        'name': 'Recording Studios Manchester',
#        'location': {'address': '1394 Ashton Old Rd',
#         'lat': 53.46861051370951,
#         'lng': -2.158323098186337,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.46861051370951,
#           'lng': -2.158323098186337}],
#         'distance': 395,
#         'postalCode': 'M11 1JX',
#         'cc': 'GB',
#         'city': 'Manchester',
#         'country': 'United Kingdom',
#         'formattedAddress': ['1394 Ashton Old Rd',
#          'Manchester',
#          'M11 1JX',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3c2ea2a2e4b1f77af2e625-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c51c57d3731ee002c81177a',
#        'name': 'Heaven Pro Clean Ltd',
#        'location': {'address': '9 Falmer Close',
#         'lat': 53.4671323,
#         'lng': -2.1542224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.4671323,
#           'lng': -2.1542224}],
#         'distance': 421,
#         'postalCode': 'M18 8XJ',
#         'cc': 'GB',
#         'city': 'Manchester',
#         'state': 'Greater Manchester',
#         'country': 'United Kingdom',
#         'formattedAddress': ['9 Falmer Close',
#          'Manchester',
#          'Greater Manchester',
#          'M18 8XJ',
#          'United Kingdom']},
#        'categories': [{'id': '545419b1498ea6ccd0202f58',
#          'name': 'Home Service',
#          'pluralName': 'Home Services & Repairs',
#          'shortName': 'Home Services',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c51c57d3731ee002c81177a-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '60a3bf8c24b9cc5577068270',
#        'name': 'Gorton Reservoir',
#        'location': {'lat': 53.462963,
#         'lng': -2.15364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 53.462963,
#           'lng': -2.15364}],
#         'distance': 465,
#         'postalCode': 'M18',
#         'cc': 'GB',
#         'city': 'Manchester',
#         'state': 'Greater Manchester',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Manchester',
#          'Greater Manchester',
#          'M18',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371be4b08b9a8d573541',
#          'name': 'Reservoir',
#          'pluralName': 'Reservoirs',
#          'shortName': 'Reservoir',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-60a3bf8c24b9cc5577068270-4'}]}]}}

# %% [markdown]
# ## Extract each venue category from data

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = []
for lat, long, ID, county, name in zip(manchester_data['latitude'], manchester_data['longitude'], manchester_data['id'], manchester_data['county'], manchester_data['name']):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        RADIUS, 
        LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for venue in results:
        venues.append((
            ID, 
            county,
            name,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
# convert the venues list into a new DataFrame
venues_df = pd.DataFrame(venues)

# define the column names
venues_df.columns = ['id', 'county', 'name', 'Area_Latitude', 'Area_Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(venues_df.shape)
venues_df.head()
# Out:
# (200, 9)
#    id              county       name  Area_Latitude  Area_Longitude  \
# 0  22  Greater Manchester  Abbey Hey       53.46514        -2.15963
# 1  22  Greater Manchester  Abbey Hey       53.46514        -2.15963
# 2  22  Greater Manchester  Abbey Hey       53.46514        -2.15963
# 3  22  Greater Manchester  Abbey Hey       53.46514        -2.15963
# 4  22  Greater Manchester  Abbey Hey       53.46514        -2.15963
#
#                              VenueName  VenueLatitude  VenueLongitude  \
# 0  Donkey Sanctuary And Therapy Centre      53.464886       -2.156117
# 1                      Manchester Vacs      53.466970       -2.157742
# 2         Recording Studios Manchester      53.468611       -2.158323
# 3                 Heaven Pro Clean Ltd      53.467132       -2.154222
# 4                     Gorton Reservoir      53.462963       -2.153640
#
#            VenueCategory
# 0                Stables
# 1      Electronics Store
# 2  Performing Arts Venue
# 3           Home Service
# 4              Reservoir

# %%
venues_df.groupby('name').count()
# Out:
#                            id  county  Area_Latitude  Area_Longitude  \
# name
# Abbey Hey                   5       5              5               5
# Abram                       5       5              5               5
# Abram Brow                  5       5              5               5
# Acre                        2       2              2               2
# Adswood                     5       5              5               5
# Affetside                   1       1              1               1
# Ainsworth                   4       4              4               4
# Alder Forest                4       4              4               4
# Alder Root                  3       3              3               3
# Alkrington Garden Village   4       4              4               4
# Alt                         1       1              1               1
# Altrincham                 39      39             39              39
# Ancoats                    48      48             48              48
# Arden Park                  4       4              4               4
# Ardwick                     9       9              9               9
# Ashley Heath                1       1              1               1
# Ashton Heath                2       2              2               2
# Ashton upon Mersey          4       4              4               4
# Ashton-in-Makerfield        5       5              5               5
# Ashton-under-Lyne          18      18             18              18
# Aspull                      4       4              4               4
# Aspull Common               2       2              2               2
# Astley                      3       3              3               3
# Astley Bridge               7       7              7               7
# Astley Green                3       3              3               3
# Atherton                    7       7              7               7
# Audenshaw                   1       1              1               1
# Austerlands                 4       4              4               4
#
#                            VenueName  VenueLatitude  VenueLongitude  \
# name
# Abbey Hey                          5              5               5
# Abram                              5              5               5
# Abram Brow                         5              5               5
# Acre                               2              2               2
# Adswood                            5              5               5
# Affetside                          1              1               1
# Ainsworth                          4              4               4
# Alder Forest                       4              4               4
# Alder Root                         3              3               3
# Alkrington Garden Village          4              4               4
# Alt                                1              1               1
# Altrincham                        39             39              39
# Ancoats                           48             48              48
# Arden Park                         4              4               4
# Ardwick                            9              9               9
# Ashley Heath                       1              1               1
# Ashton Heath                       2              2               2
# Ashton upon Mersey                 4              4               4
# Ashton-in-Makerfield               5              5               5
# Ashton-under-Lyne                 18             18              18
# Aspull                             4              4               4
# Aspull Common                      2              2               2
# Astley                             3              3               3
# Astley Bridge                      7              7               7
# Astley Green                       3              3               3
# Atherton                           7              7               7
# Audenshaw                          1              1               1
# Austerlands                        4              4               4
#
#                            VenueCategory
# name
# Abbey Hey                              5
# Abram                                  5
# Abram Brow                             5
# Acre                                   2
# Adswood                                5
# Affetside                              1
# Ainsworth                              4
# Alder Forest                           4
# Alder Root                             3
# Alkrington Garden Village              4
# Alt                                    1
# Altrincham                            39
# Ancoats                               48
# Arden Park                             4
# Ardwick                                9
# Ashley Heath                           1
# Ashton Heath                           2
# Ashton upon Mersey                     4
# Ashton-in-Makerfield                   5
# Ashton-under-Lyne                     18
# Aspull                                 4
# Aspull Common                          2
# Astley                                 3
# Astley Bridge                          7
# Astley Green                           3
# Atherton                               7
# Audenshaw                              1
# Austerlands                            4

# %% [markdown]
# Here we see how many unique categories there are

# %%
print('There are {} uniques categories.'.format(len(venues_df['VenueCategory'].unique())))
# Out:
# There are 77 uniques categories.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ## Lets apply one hot encoding to better understand the data

# %%
Manchester_onehot = pd.get_dummies(venues_df[['VenueCategory']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Manchester_onehot['name'] = venues_df['name'] 

# move neighborhood column to the first column
fixed_columns = [Manchester_onehot.columns[-1]] + list(Manchester_onehot.columns[:-1])
Manchester_onehot = Manchester_onehot[fixed_columns]

Manchester_onehot.tail()
# Out:
#             name  American Restaurant  Arts & Crafts Store  Auto Garage  \
# 195    Audenshaw                    0                    0            0
# 196  Austerlands                    0                    0            0
# 197  Austerlands                    0                    0            0
# 198  Austerlands                    0                    0            0
# 199  Austerlands                    0                    0            0
#
#      Bakery  Bar  Beer Bar  Bookstore  Brazilian Restaurant  Breakfast Spot  \
# 195       0    0         0          0                     0               0
# 196       0    0         0          0                     0               0
# 197       0    0         0          0                     0               0
# 198       0    0         0          0                     0               0
# 199       0    0         0          0                     0               0
#
#      ...  Supermarket  Sushi Restaurant  Tea Room  Thai Restaurant  Trail  \
# 195  ...            0                 0         0                0      0
# 196  ...            0                 0         0                0      0
# 197  ...            0                 0         0                0      0
# 198  ...            0                 0         0                0      0
# 199  ...            0                 0         0                0      0
#
#      Train Station  Tram Station  Vegetarian / Vegan Restaurant  \
# 195              0             0                              0
# 196              0             0                              0
# 197              0             0                              0
# 198              0             0                              0
# 199              0             0                              0
#
#      Warehouse Store  Wine Bar
# 195                0         0
# 196                0         0
# 197                0         0
# 198                0         0
# 199                0         0
#
# [5 rows x 78 columns]

# %%
Manchester_onehot.shape
# Out:
# (200, 78)

# %%
Manchester_grouped = Manchester_onehot.groupby('name').mean().reset_index()
Manchester_grouped
# Out:
#                          name  American Restaurant  Arts & Crafts Store  \
# 0                   Abbey Hey             0.000000             0.000000
# 1                       Abram             0.000000             0.000000
# 2                  Abram Brow             0.000000             0.000000
# 3                        Acre             0.000000             0.000000
# 4                     Adswood             0.000000             0.000000
# 5                   Affetside             0.000000             0.000000
# 6                   Ainsworth             0.000000             0.000000
# 7                Alder Forest             0.000000             0.000000
# 8                  Alder Root             0.000000             0.000000
# 9   Alkrington Garden Village             0.000000             0.000000
# 10                        Alt             0.000000             0.000000
# 11                 Altrincham             0.025641             0.000000
# 12                    Ancoats             0.020833             0.020833
# 13                 Arden Park             0.000000             0.000000
# 14                    Ardwick             0.000000             0.000000
# 15               Ashley Heath             0.000000             0.000000
# 16               Ashton Heath             0.000000             0.000000
# 17         Ashton upon Mersey             0.000000             0.000000
# 18       Ashton-in-Makerfield             0.000000             0.000000
# 19          Ashton-under-Lyne             0.000000             0.000000
# 20                     Aspull             0.000000             0.000000
# 21              Aspull Common             0.000000             0.000000
# 22                     Astley             0.000000             0.000000
# 23              Astley Bridge             0.000000             0.000000
# 24               Astley Green             0.000000             0.000000
# 25                   Atherton             0.000000             0.000000
# 26                  Audenshaw             0.000000             0.000000
# 27                Austerlands             0.000000             0.000000
#
#     Auto Garage    Bakery       Bar  Beer Bar  Bookstore  \
# 0      0.000000  0.000000  0.000000    0.0000   0.000000
# 1      0.000000  0.000000  0.200000    0.0000   0.000000
# 2      0.000000  0.000000  0.200000    0.0000   0.000000
# 3      0.000000  0.000000  0.000000    0.0000   0.000000
# 4      0.000000  0.000000  0.000000    0.0000   0.000000
# 5      0.000000  0.000000  0.000000    0.0000   0.000000
# 6      0.000000  0.000000  0.250000    0.0000   0.000000
# 7      0.000000  0.000000  0.000000    0.0000   0.000000
# 8      0.333333  0.000000  0.000000    0.0000   0.000000
# 9      0.000000  0.000000  0.000000    0.0000   0.000000
# 10     0.000000  0.000000  0.000000    0.0000   0.000000
# 11     0.025641  0.000000  0.102564    0.0000   0.025641
# 12     0.000000  0.041667  0.062500    0.0625   0.020833
# 13     0.250000  0.000000  0.000000    0.0000   0.000000
# 14     0.000000  0.000000  0.000000    0.0000   0.000000
# 15     0.000000  0.000000  0.000000    0.0000   0.000000
# 16     0.000000  0.000000  0.000000    0.0000   0.000000
# 17     0.000000  0.000000  0.000000    0.0000   0.000000
# 18     0.000000  0.000000  0.000000    0.0000   0.000000
# 19     0.000000  0.000000  0.000000    0.0000   0.000000
# 20     0.000000  0.000000  0.000000    0.0000   0.000000
# 21     0.000000  0.000000  0.000000    0.0000   0.000000
# 22     0.000000  0.000000  0.000000    0.0000   0.000000
# 23     0.000000  0.000000  0.000000    0.0000   0.000000
# 24     0.000000  0.000000  0.333333    0.0000   0.000000
# 25     0.000000  0.000000  0.142857    0.0000   0.000000
# 26     0.000000  0.000000  0.000000    0.0000   0.000000
# 27     0.000000  0.000000  0.000000    0.0000   0.000000
#
#     Brazilian Restaurant  Breakfast Spot  ...  Supermarket  Sushi Restaurant  \
# 0               0.000000        0.000000  ...     0.000000          0.000000
# 1               0.000000        0.000000  ...     0.000000          0.000000
# 2               0.000000        0.000000  ...     0.000000          0.000000
# 3               0.000000        0.000000  ...     0.000000          0.000000
# 4               0.000000        0.200000  ...     0.000000          0.000000
# 5               0.000000        0.000000  ...     0.000000          0.000000
# 6               0.000000        0.000000  ...     0.000000          0.000000
# 7               0.000000        0.000000  ...     0.000000          0.000000
# 8               0.000000        0.000000  ...     0.333333          0.000000
# 9               0.000000        0.000000  ...     0.000000          0.000000
# 10              0.000000        0.000000  ...     0.000000          0.000000
# 11              0.025641        0.025641  ...     0.025641          0.000000
# 12              0.020833        0.000000  ...     0.000000          0.020833
# 13              0.000000        0.000000  ...     0.250000          0.000000
# 14              0.000000        0.000000  ...     0.000000          0.000000
# 15              0.000000        0.000000  ...     0.000000          0.000000
# 16              0.000000        0.000000  ...     0.500000          0.000000
# 17              0.000000        0.000000  ...     0.000000          0.000000
# 18              0.000000        0.000000  ...     0.000000          0.000000
# 19              0.000000        0.000000  ...     0.000000          0.000000
# 20              0.000000        0.000000  ...     0.000000          0.000000
# 21              0.000000        0.000000  ...     0.000000          0.000000
# 22              0.000000        0.000000  ...     0.000000          0.000000
# 23              0.000000        0.000000  ...     0.285714          0.000000
# 24              0.000000        0.000000  ...     0.000000          0.000000
# 25              0.000000        0.000000  ...     0.285714          0.000000
# 26              0.000000        0.000000  ...     0.000000          0.000000
# 27              0.000000        0.000000  ...     0.000000          0.000000
#
#     Tea Room  Thai Restaurant  Trail  Train Station  Tram Station  \
# 0   0.000000         0.000000    0.0       0.000000      0.000000
# 1   0.000000         0.000000    0.2       0.000000      0.000000
# 2   0.000000         0.000000    0.2       0.000000      0.000000
# 3   0.000000         0.000000    0.0       0.000000      0.500000
# 4   0.000000         0.000000    0.0       0.000000      0.000000
# 5   0.000000         0.000000    0.0       0.000000      0.000000
# 6   0.000000         0.000000    0.0       0.000000      0.000000
# 7   0.000000         0.000000    0.0       0.000000      0.000000
# 8   0.000000         0.000000    0.0       0.000000      0.000000
# 9   0.000000         0.000000    0.0       0.000000      0.000000
# 10  0.000000         0.000000    0.0       0.000000      0.000000
# 11  0.000000         0.025641    0.0       0.000000      0.025641
# 12  0.020833         0.000000    0.0       0.020833      0.000000
# 13  0.000000         0.000000    0.0       0.000000      0.000000
# 14  0.000000         0.000000    0.0       0.000000      0.000000
# 15  0.000000         0.000000    0.0       0.000000      0.000000
# 16  0.000000         0.000000    0.0       0.000000      0.000000
# 17  0.000000         0.000000    0.0       0.000000      0.000000
# 18  0.000000         0.000000    0.0       0.000000      0.000000
# 19  0.000000         0.000000    0.0       0.055556      0.000000
# 20  0.000000         0.000000    0.0       0.000000      0.000000
# 21  0.000000         0.000000    0.0       0.000000      0.000000
# 22  0.333333         0.000000    0.0       0.000000      0.000000
# 23  0.000000         0.000000    0.0       0.000000      0.000000
# 24  0.000000         0.000000    0.0       0.000000      0.000000
# 25  0.000000         0.000000    0.0       0.000000      0.000000
# 26  0.000000         0.000000    0.0       0.000000      0.000000
# 27  0.000000         0.000000    0.0       0.000000      0.000000
#
#     Vegetarian / Vegan Restaurant  Warehouse Store  Wine Bar
# 0                        0.000000         0.000000  0.000000
# 1                        0.000000         0.000000  0.000000
# 2                        0.000000         0.000000  0.000000
# 3                        0.000000         0.000000  0.000000
# 4                        0.000000         0.000000  0.000000
# 5                        0.000000         0.000000  0.000000
# 6                        0.000000         0.000000  0.000000
# 7                        0.000000         0.000000  0.000000
# 8                        0.000000         0.000000  0.000000
# 9                        0.000000         0.000000  0.000000
# 10                       0.000000         0.000000  0.000000
# 11                       0.000000         0.000000  0.025641
# 12                       0.000000         0.000000  0.000000
# 13                       0.000000         0.000000  0.000000
# 14                       0.000000         0.000000  0.000000
# 15                       0.000000         0.000000  0.000000
# 16                       0.000000         0.000000  0.000000
# 17                       0.000000         0.000000  0.000000
# 18                       0.000000         0.000000  0.000000
# 19                       0.111111         0.055556  0.000000
# 20                       0.000000         0.000000  0.000000
# 21                       0.000000         0.000000  0.000000
# 22                       0.000000         0.000000  0.000000
# 23                       0.000000         0.000000  0.000000
# 24                       0.000000         0.000000  0.000000
# 25                       0.000000         0.000000  0.000000
# 26                       0.000000         0.000000  0.000000
# 27                       0.000000         0.000000  0.000000
#
# [28 rows x 78 columns]

# %%
Manchester_grouped.shape
# Out:
# (28, 78)

# %% [markdown]
# ## Lets find the top 5 venues for each area in the city

# %%
num_top_venues = 5

for hood in Manchester_grouped['name']:
    print("----"+hood+"----")
    temp = Manchester_grouped[Manchester_grouped['name'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Abbey Hey----
#                    venue  freq
# 0              Reservoir   0.2
# 1           Home Service   0.2
# 2                Stables   0.2
# 3  Performing Arts Venue   0.2
# 4      Electronics Store   0.2
#
#
# ----Abram----
#                 venue  freq
# 0                 Pub   0.2
# 1                 Bar   0.2
# 2               Trail   0.2
# 3                Park   0.2
# 4  Chinese Restaurant   0.2
#
#
# ----Abram Brow----
#                 venue  freq
# 0                 Pub   0.2
# 1                 Bar   0.2
# 2               Trail   0.2
# 3                Park   0.2
# 4  Chinese Restaurant   0.2
#
#
# ----Acre----
#                  venue  freq
# 0    Convenience Store   0.5
# 1         Tram Station   0.5
# 2  American Restaurant   0.0
# 3            Pet Store   0.0
# 4                  Pub   0.0
#
#
# ----Adswood----
#             venue  freq
# 0    Liquor Store   0.2
# 1       Pet Store   0.2
# 2             Pub   0.2
# 3  Breakfast Spot   0.2
# 4            Park   0.2
#
#
# ----Affetside----
#                    venue  freq
# 0                    Pub   1.0
# 1    American Restaurant   0.0
# 2              Pet Store   0.0
# 3             Racecourse   0.0
# 4  Portuguese Restaurant   0.0
#
#
# ----Ainsworth----
#           venue  freq
# 0      Bus Stop  0.25
# 1           Pub  0.25
# 2           Bar  0.25
# 3  Home Service  0.25
# 4     Pet Store  0.00
#
#
# ----Alder Forest----
#                  venue  freq
# 0       Cricket Ground  0.25
# 1         Home Service  0.25
# 2                  Pub  0.25
# 3                 Park  0.25
# 4  American Restaurant  0.00
#
#
# ----Alder Root----
#                  venue  freq
# 0          Supermarket  0.33
# 1          Auto Garage  0.33
# 2         Home Service  0.33
# 3  American Restaurant  0.00
# 4                  Pub  0.00
#
#
# ----Alkrington Garden Village----
#                  venue  freq
# 0      Nature Preserve  0.25
# 1        Grocery Store  0.25
# 2              Gay Bar  0.25
# 3             Pharmacy  0.25
# 4  American Restaurant  0.00
#
#
# ----Alt----
#                    venue  freq
# 0                    Pub   1.0
# 1    American Restaurant   0.0
# 2              Pet Store   0.0
# 3             Racecourse   0.0
# 4  Portuguese Restaurant   0.0
#
#
# ----Altrincham----
#               venue  freq
# 0               Bar  0.10
# 1       Coffee Shop  0.10
# 2              Café  0.05
# 3  Department Store  0.05
# 4               Pub  0.05
#
#
# ----Ancoats----
#             venue  freq
# 0     Coffee Shop  0.17
# 1        Platform  0.06
# 2             Bar  0.06
# 3        Beer Bar  0.06
# 4  Sandwich Place  0.04
#
#
# ----Arden Park----
#                   venue  freq
# 0           Supermarket  0.25
# 1           Auto Garage  0.25
# 2                   Pub  0.25
# 3  Fast Food Restaurant  0.25
# 4   American Restaurant  0.00
#
#
# ----Ardwick----
#                venue  freq
# 0            Brewery  0.22
# 1        Gas Station  0.11
# 2  Electronics Store  0.11
# 3     Sandwich Place  0.11
# 4               Park  0.11
#
#
# ----Ashley Heath----
#                    venue  freq
# 0             Restaurant   1.0
# 1              Pet Store   0.0
# 2             Racecourse   0.0
# 3                    Pub   0.0
# 4  Portuguese Restaurant   0.0
#
#
# ----Ashton Heath----
#                    venue  freq
# 0             Racecourse   0.5
# 1            Supermarket   0.5
# 2                    Pub   0.0
# 3  Portuguese Restaurant   0.0
# 4               Platform   0.0
#
#
# ----Ashton upon Mersey----
#                venue  freq
# 0      Grocery Store  0.50
# 1               Park  0.25
# 2  Indian Restaurant  0.25
# 3          Pet Store  0.00
# 4                Pub  0.00
#
#
# ----Ashton-in-Makerfield----
#                   venue  freq
# 0                   Pub   0.4
# 1        Sandwich Place   0.2
# 2  Fast Food Restaurant   0.2
# 3         Grocery Store   0.2
# 4   American Restaurant   0.0
#
#
# ----Ashton-under-Lyne----
#                            venue  freq
# 0                         Market  0.11
# 1  Vegetarian / Vegan Restaurant  0.11
# 2             Italian Restaurant  0.06
# 3                           Café  0.06
# 4         Furniture / Home Store  0.06
#
#
# ----Aspull----
#                venue  freq
# 0      Event Service  0.25
# 1  Indian Restaurant  0.25
# 2  Convenience Store  0.25
# 3      Grocery Store  0.25
# 4           Pharmacy  0.00
#
#
# ----Aspull Common----
#                    venue  freq
# 0          Deli / Bodega   0.5
# 1                    Pub   0.5
# 2              Pet Store   0.0
# 3             Racecourse   0.0
# 4  Portuguese Restaurant   0.0
#
#
# ----Astley----
#                    venue  freq
# 0      Indian Restaurant  0.33
# 1                    Pub  0.33
# 2               Tea Room  0.33
# 3    American Restaurant  0.00
# 4  Performing Arts Venue  0.00
#
#
# ----Astley Bridge----
#                     venue  freq
# 0             Supermarket  0.29
# 1                     Pub  0.14
# 2             Pizza Place  0.14
# 3      Chinese Restaurant  0.14
# 4  Furniture / Home Store  0.14
#
#
# ----Astley Green----
#                  venue  freq
# 0               Museum  0.33
# 1                  Bar  0.33
# 2                 Park  0.33
# 3  American Restaurant  0.00
# 4             Pharmacy  0.00
#
#
# ----Atherton----
#             venue  freq
# 0     Supermarket  0.29
# 1    Soccer Field  0.14
# 2     Roller Rink  0.14
# 3  Sandwich Place  0.14
# 4             Pub  0.14
#
#
# ----Audenshaw----
#                    venue  freq
# 0      Indian Restaurant   1.0
# 1    American Restaurant   0.0
# 2  Performing Arts Venue   0.0
# 3                    Pub   0.0
# 4  Portuguese Restaurant   0.0
#
#
# ----Austerlands----
#                  venue  freq
# 0                  Pub  0.25
# 1          Music Venue  0.25
# 2            Gastropub  0.25
# 3          Sports Club  0.25
# 4  American Restaurant  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
area_venues_sorted = pd.DataFrame(columns=columns)
area_venues_sorted['name'] = Manchester_grouped['name']

for ind in np.arange(Manchester_grouped.shape[0]):
    area_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Manchester_grouped.iloc[ind, :], num_top_venues)

area_venues_sorted.head()
# Out:
#          name 1st Most Common Venue  2nd Most Common Venue  \
# 0   Abbey Hey          Home Service  Performing Arts Venue
# 1       Abram                   Pub                  Trail
# 2  Abram Brow                   Pub                  Trail
# 3        Acre     Convenience Store           Tram Station
# 4     Adswood                  Park           Liquor Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0             Reservoir     Electronics Store               Stables
# 1                   Bar    Chinese Restaurant                  Park
# 2                   Bar    Chinese Restaurant                  Park
# 3     French Restaurant      Department Store     Electronics Store
# 4             Pet Store        Breakfast Spot                   Pub
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0               Gay Bar             Gastropub           Gas Station
# 1     Fish & Chips Shop      Department Store     Electronics Store
# 2     Fish & Chips Shop      Department Store     Electronics Store
# 3         Event Service    Falafel Restaurant        Farmers Market
# 4              Wine Bar     Electronics Store         Event Service
#
#     9th Most Common Venue 10th Most Common Venue
# 0  Furniture / Home Store      French Restaurant
# 1           Event Service     Falafel Restaurant
# 2           Event Service     Falafel Restaurant
# 3    Fast Food Restaurant      Fish & Chips Shop
# 4      Falafel Restaurant         Farmers Market

# %% [markdown]
# ## Applying K-Means to data

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
# set number of clusters
kclusters = 5

Manchester_grouped_clustering = Manchester_grouped.drop('name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Manchester_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 0, 0, 1, 0, 0, 4, 0])

# %%
# add clustering labels
area_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Manchester_merged = manchester_data

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
Manchester_merged = Manchester_merged.join(area_venues_sorted.set_index('name'), on='name')



Manchester_merged.dropna(inplace=True)
Manchester_merged.head() # check the last columns!
# Out:
#       id        name              county  latitude  longitude           type  \
# 21    22   Abbey Hey  Greater Manchester  53.46514   -2.15963       Locality
# 175  176       Abram  Greater Manchester  53.50949   -2.59264        Village
# 176  177  Abram Brow  Greater Manchester  53.50791   -2.59027  Suburban Area
# 285  286        Acre  Greater Manchester  53.55218   -2.09701  Suburban Area
# 369  370     Adswood  Greater Manchester  53.39130   -2.16962  Suburban Area
#
#      Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 21              0.0          Home Service  Performing Arts Venue
# 175             0.0                   Pub                  Trail
# 176             0.0                   Pub                  Trail
# 285             0.0     Convenience Store           Tram Station
# 369             0.0                  Park           Liquor Store
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 21              Reservoir     Electronics Store               Stables
# 175                   Bar    Chinese Restaurant                  Park
# 176                   Bar    Chinese Restaurant                  Park
# 285     French Restaurant      Department Store     Electronics Store
# 369             Pet Store        Breakfast Spot                   Pub
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 21                Gay Bar             Gastropub           Gas Station
# 175     Fish & Chips Shop      Department Store     Electronics Store
# 176     Fish & Chips Shop      Department Store     Electronics Store
# 285         Event Service    Falafel Restaurant        Farmers Market
# 369              Wine Bar     Electronics Store         Event Service
#
#       9th Most Common Venue 10th Most Common Venue
# 21   Furniture / Home Store      French Restaurant
# 175           Event Service     Falafel Restaurant
# 176           Event Service     Falafel Restaurant
# 285    Fast Food Restaurant      Fish & Chips Shop
# 369      Falafel Restaurant         Farmers Market

# %% [markdown]
# ## Creating the cluster map

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Manchester_merged['latitude'], Manchester_merged['longitude'], Manchester_merged['name'], Manchester_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_b15d3a91d01c45d0acc8ea8764348c6a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b15d3a91d01c45d0acc8ea8764348c6a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b15d3a91d01c45d0acc8ea8764348c6a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_b15d3a91d01c45d0acc8ea8764348c6a%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B53.4794892%2C-2.2451148%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Cluster 1

# %%
Manchester_merged.loc[Manchester_merged['Cluster Labels'] == 0, Manchester_merged.columns[[1] + list(range(5, Manchester_merged.shape[1]))]]
# Out:
#                            name           type  Cluster Labels  \
# 21                    Abbey Hey       Locality             0.0
# 175                       Abram        Village             0.0
# 176                  Abram Brow  Suburban Area             0.0
# 285                        Acre  Suburban Area             0.0
# 369                     Adswood  Suburban Area             0.0
# 422                   Ainsworth        Village             0.0
# 520                Alder Forest  Suburban Area             0.0
# 607   Alkrington Garden Village  Suburban Area             0.0
# 767                  Altrincham           Town             0.0
# 863                     Ancoats  Suburban Area             0.0
# 1149                    Ardwick  Suburban Area             0.0
# 1435       Ashton-in-Makerfield           Town             0.0
# 1440          Ashton-under-Lyne           Town             0.0
# 1441         Ashton upon Mersey  Suburban Area             0.0
# 1489                     Aspull        Village             0.0
# 1506                     Astley        Village             0.0
# 1514               Astley Green  Suburban Area             0.0
# 1715                Austerlands  Suburban Area             0.0
#
#               1st Most Common Venue  2nd Most Common Venue  \
# 21                     Home Service  Performing Arts Venue
# 175                             Pub                  Trail
# 176                             Pub                  Trail
# 285               Convenience Store           Tram Station
# 369                            Park           Liquor Store
# 422                    Home Service                    Bar
# 520                  Cricket Ground                    Pub
# 607                   Grocery Store                Gay Bar
# 767                             Bar            Coffee Shop
# 863                     Coffee Shop               Platform
# 1149                        Brewery                   Park
# 1435                            Pub   Fast Food Restaurant
# 1440  Vegetarian / Vegan Restaurant                 Market
# 1441                  Grocery Store                   Park
# 1489              Indian Restaurant      Convenience Store
# 1506              Indian Restaurant               Tea Room
# 1514                           Park                    Bar
# 1715                      Gastropub            Music Venue
#
#      3rd Most Common Venue    4th Most Common Venue   5th Most Common Venue  \
# 21               Reservoir        Electronics Store                 Stables
# 175                    Bar       Chinese Restaurant                    Park
# 176                    Bar       Chinese Restaurant                    Park
# 285      French Restaurant         Department Store       Electronics Store
# 369              Pet Store           Breakfast Spot                     Pub
# 422                    Pub                 Bus Stop                Wine Bar
# 520                   Park             Home Service                  Bakery
# 607        Nature Preserve                 Pharmacy                Wine Bar
# 767       Department Store              Pizza Place                    Café
# 863                    Bar                 Beer Bar          Sandwich Place
# 1149     Electronics Store             Concert Hall           Grocery Store
# 1435         Grocery Store           Sandwich Place           Deli / Bodega
# 1440    Italian Restaurant  Scandinavian Restaurant  Furniture / Home Store
# 1441     Indian Restaurant                 Gym Pool       Fish & Chips Shop
# 1489         Grocery Store            Event Service       Fish & Chips Shop
# 1506                   Pub        French Restaurant        Department Store
# 1514                Museum                 Wine Bar       Electronics Store
# 1715                   Pub              Sports Club                Wine Bar
#
#      6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 21                 Gay Bar             Gastropub           Gas Station
# 175      Fish & Chips Shop      Department Store     Electronics Store
# 176      Fish & Chips Shop      Department Store     Electronics Store
# 285          Event Service    Falafel Restaurant        Farmers Market
# 369               Wine Bar     Electronics Store         Event Service
# 422      French Restaurant     Electronics Store         Event Service
# 520      French Restaurant         Event Service    Falafel Restaurant
# 607      Fish & Chips Shop     Electronics Store         Event Service
# 767         Clothing Store                   Pub     French Restaurant
# 863                 Bakery           Pizza Place     Indian Restaurant
# 1149           Gas Station        Sandwich Place          Soccer Field
# 1435      Department Store     Electronics Store         Event Service
# 1440       Warehouse Store  Fast Food Restaurant             Newsagent
# 1441      Department Store     Electronics Store         Event Service
# 1489      Department Store     Electronics Store    Falafel Restaurant
# 1506     Electronics Store         Event Service    Falafel Restaurant
# 1514         Event Service    Falafel Restaurant        Farmers Market
# 1715     Fish & Chips Shop      Department Store     Electronics Store
#
#        9th Most Common Venue 10th Most Common Venue
# 21    Furniture / Home Store      French Restaurant
# 175            Event Service     Falafel Restaurant
# 176            Event Service     Falafel Restaurant
# 285     Fast Food Restaurant      Fish & Chips Shop
# 369       Falafel Restaurant         Farmers Market
# 422       Falafel Restaurant         Farmers Market
# 520           Farmers Market   Fast Food Restaurant
# 607       Falafel Restaurant         Farmers Market
# 767                 Pharmacy              Newsagent
# 863                    Hotel        Piercing Parlor
# 1149                Wine Bar          Event Service
# 1435      Falafel Restaurant         Farmers Market
# 1440               Pet Store               Pharmacy
# 1441      Falafel Restaurant         Farmers Market
# 1489          Farmers Market   Fast Food Restaurant
# 1506          Farmers Market   Fast Food Restaurant
# 1514    Fast Food Restaurant      Fish & Chips Shop
# 1715           Event Service     Falafel Restaurant

# %% [markdown]
# ## Cluster 2

# %%
Manchester_merged.loc[Manchester_merged['Cluster Labels'] == 1, Manchester_merged.columns[[1] + list(range(5, Manchester_merged.shape[1]))]]
# Out:
#                name           type  Cluster Labels 1st Most Common Venue  \
# 378       Affetside        Village             1.0                   Pub
# 741             Alt  Suburban Area             1.0                   Pub
# 1490  Aspull Common  Suburban Area             1.0                   Pub
#
#      2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 378      French Restaurant      Department Store     Electronics Store
# 741      French Restaurant      Department Store     Electronics Store
# 1490         Deli / Bodega     French Restaurant      Department Store
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 378          Event Service    Falafel Restaurant        Farmers Market
# 741          Event Service    Falafel Restaurant        Farmers Market
# 1490     Electronics Store         Event Service    Falafel Restaurant
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 378   Fast Food Restaurant     Fish & Chips Shop               Wine Bar
# 741   Fast Food Restaurant     Fish & Chips Shop               Wine Bar
# 1490        Farmers Market  Fast Food Restaurant      Fish & Chips Shop

# %% [markdown]
# ## Cluster 3

# %%
Manchester_merged.loc[Manchester_merged['Cluster Labels'] == 2, Manchester_merged.columns[[1] + list(range(5, Manchester_merged.shape[1]))]]
# Out:
#            name      type  Cluster Labels 1st Most Common Venue  \
# 1675  Audenshaw  Locality             2.0     Indian Restaurant
#
#      2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1675              Wine Bar     French Restaurant      Department Store
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1675     Electronics Store         Event Service    Falafel Restaurant
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1675        Farmers Market  Fast Food Restaurant      Fish & Chips Shop

# %% [markdown]
# ## Cluster 4

# %%
Manchester_merged.loc[Manchester_merged['Cluster Labels'] == 3, Manchester_merged.columns[[1] + list(range(5, Manchester_merged.shape[1]))]]
# Out:
#               name           type  Cluster Labels 1st Most Common Venue  \
# 1388  Ashley Heath  Suburban Area             3.0            Restaurant
#
#      2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1388              Wine Bar        Cricket Ground      Department Store
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1388     Electronics Store         Event Service    Falafel Restaurant
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1388        Farmers Market  Fast Food Restaurant      Fish & Chips Shop

# %% [markdown]
# ## Cluster 5

# %%
Manchester_merged.loc[Manchester_merged['Cluster Labels'] == 4, Manchester_merged.columns[[1] + list(range(5, Manchester_merged.shape[1]))]]
# Out:
#                name           type  Cluster Labels 1st Most Common Venue  \
# 533      Alder Root  Suburban Area             4.0          Home Service
# 1075     Arden Park  Suburban Area             4.0           Auto Garage
# 1434   Ashton Heath  Suburban Area             4.0           Supermarket
# 1511  Astley Bridge  Suburban Area             4.0           Supermarket
# 1589       Atherton           Town             4.0           Supermarket
#
#      2nd Most Common Venue 3rd Most Common Venue   4th Most Common Venue  \
# 533            Auto Garage           Supermarket                Wine Bar
# 1075  Fast Food Restaurant           Supermarket                     Pub
# 1434            Racecourse              Wine Bar       Fish & Chips Shop
# 1511           Pizza Place    Chinese Restaurant  Furniture / Home Store
# 1589                   Pub                   Bar             Roller Rink
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 533      French Restaurant     Electronics Store         Event Service
# 1075              Wine Bar     Fish & Chips Shop      Department Store
# 1434         Deli / Bodega      Department Store     Electronics Store
# 1511             Pet Store                   Pub              Wine Bar
# 1589        Sandwich Place          Soccer Field              Wine Bar
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 533     Falafel Restaurant        Farmers Market   Fast Food Restaurant
# 1075     Electronics Store         Event Service     Falafel Restaurant
# 1434         Event Service    Falafel Restaurant         Farmers Market
# 1511        Farmers Market      Department Store      Electronics Store
# 1589  Fast Food Restaurant      Department Store      Electronics Store

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Per inspection of the clustering map and the results of the clustering above we can state that the majority of areas within the city of Manchester fall under cluster 1. We can also see that the majority of cluster 1 is relatively close to the city centre and thus would probably be the most popular spots to visit on my trip

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# The purpose of this project was to identify the places of interest within the city of Manchester that I would most likely visiti while on my trip to the city.
